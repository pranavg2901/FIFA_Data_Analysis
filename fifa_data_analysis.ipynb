# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sc

# %%
fifa = pd.read_csv('players_20.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
# total no. of cells
18278*104
# Out:
# 1900912

# %%
# display all column names
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
#nationality of players
fifa['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
# top 10 countries
fifa['nationality'].value_counts()[:10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
# bar plot for top 10 countries player ratio
plt.figure(figsize=(8,8))
plt.bar(list(fifa['nationality'].value_counts()[:10].keys()),list(fifa['nationality'].value_counts()[:10]),color="g")
plt.show()

# %%
player_salary=fifa[['short_name','wage_eur']]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
#Asceding/descding order
player_salary=player_salary.sort_values(by=['wage_eur'],ascending=False)
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
# bar plot for two values: short name and salary
plt.figure(figsize=(8,8))
plt.bar(list(player_salary['short_name'])[:5],list(player_salary['wage_eur'])[:5],color=["Blue","red","Green","Yellow","Pink"])
plt.show()

# %%
#only germany data
fifa['nationality']=='Germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
Germany=fifa[fifa['nationality']=='Germany']
Germany.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...
#
#         short_name              long_name  age         dob  height_cm  \
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31        M. Neuer           Manuel Neuer   33  1986-03-27        193
# ...

# %%
# sort by height
Germany.sort_values(by=['height_cm']).head()
# Out:
#        sofifa_id                                         player_url  \
# 11612     248879  https://sofifa.com/player/248879/kevin-holzwei...
# 15960     247284  https://sofifa.com/player/247284/patrick-finge...
# 11380     250936  https://sofifa.com/player/250936/seref-ozcan/2...
# 6364      189209  https://sofifa.com/player/189209/sascha-bigalk...
# 17889     239129  https://sofifa.com/player/239129/jakob-gesien/...
#
#           short_name         long_name  age         dob  height_cm  weight_kg  \
# 11612  K. Holzweiler  Kevin Holzweiler   24  1994-10-16        164         60
# 15960      P. Finger    Patrick Finger   18  2001-01-01        166         61
# 11380       S. Özcan       Seref Özcan   23  1996-06-08        166         65
# 6364      S. Bigalke    Sascha Bigalke   29  1990-01-08        167         60
# 17889      J. Gesien      Jakob Gesien   21  1998-01-11        167         58
#
#       nationality                 club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
# sort height by descending order
Germany.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
#
#            short_name            long_name  age         dob  height_cm  \
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
# 1217         M. Esser        Michael Esser   31  1987-11-22        198
# 1389    L. Unnerstall      Lars Unnerstall   28  1990-07-20        198
# 11859  D. Stroh-Engel  Dominik Stroh-Engel   33  1985-11-27        197
# 13576    L. Watkowiak      Lukas Watkowiak   23  1996-03-06        197
#
#        weight_kg nationality                club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
# sort by weight
Germany.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
#
#           short_name        long_name  age         dob  height_cm  weight_kg  \
# 13576   L. Watkowiak  Lukas Watkowiak   23  1996-03-06        197        103
# 1389   L. Unnerstall  Lars Unnerstall   28  1990-07-20        198        103
# 518      R. Fährmann    Ralf Fährmann   30  1988-09-27        197         98
# 1217        M. Esser    Michael Esser   31  1987-11-22        198         97
# 77           N. Süle      Niklas Süle   23  1995-09-03        195         97
#
#       nationality                club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
# sort by salary
Germany.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 146     186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
#
#         short_name              long_name  age         dob  height_cm  \
# 36        T. Kroos             Toni Kroos   29  1990-01-04        183
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 55         L. Sané             Leroy Sané   23  1996-01-11        183
# 146    I. Gündoğan         İlkay Gündoğan   28  1990-10-24        180
# 70       T. Müller          Thomas Müller   29  1989-09-13        186
#
#      weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
Germany[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000

# %%
# Shooting skills

# %%
player_shooting=fifa[['short_name','shooting']]

# %%
player_shooting.head(10)
# Out:
#           short_name  shooting
# 0           L. Messi      92.0
# 1  Cristiano Ronaldo      93.0
# 2          Neymar Jr      85.0
# 3           J. Oblak       NaN
# 4          E. Hazard      83.0
# 5       K. De Bruyne      86.0
# 6      M. ter Stegen       NaN
# 7        V. van Dijk      60.0
# 8          L. Modrić      76.0
# 9           M. Salah      86.0

# %%
player_shooting.sort_values(by=['shooting'],ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
player_shooting=player_shooting.sort_values(by=['shooting'],ascending=False)
player_shooting.head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_shooting['short_name'])[:5],list(player_shooting['shooting'])[:5],color=["Blue","red","Green","Yellow","Pink"])
plt.show()

# %%
# defending

# %%
player_defending=fifa[['short_name','defending','nationality','club']]

# %%
player_defending.head()
# Out:
#           short_name  defending nationality                 club
# 0           L. Messi       39.0   Argentina         FC Barcelona
# 1  Cristiano Ronaldo       35.0    Portugal             Juventus
# 2          Neymar Jr       32.0      Brazil  Paris Saint-Germain
# 3           J. Oblak        NaN    Slovenia      Atlético Madrid
# 4          E. Hazard       35.0     Belgium          Real Madrid

# %%
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
# data who is play for club liverpool
liver = fifa[fifa['club']=='Liverpool']

# %%
liver.head()
# Out:
#     sofifa_id                                         player_url  \
# 7      203376  https://sofifa.com/player/203376/virgil-van-di...
# 9      209331  https://sofifa.com/player/209331/mohamed-salah...
# 13     212831  https://sofifa.com/player/212831/alisson-ramse...
# 39     208722  https://sofifa.com/player/208722/sadio-mane/20...
# 63     201942  https://sofifa.com/player/201942/roberto-firmi...
#
#          short_name                            long_name  age         dob  \
# 7       V. van Dijk                      Virgil van Dijk   27  1991-07-08
# 9          M. Salah                 Mohamed  Salah Ghaly   27  1992-06-15
# 13          Alisson                Alisson Ramses Becker   26  1992-10-02
# 39          S. Mané                           Sadio Mané   27  1992-04-10
# 63  Roberto Firmino  Roberto Firmino Barbosa de Oliveira   27  1991-10-02
#
#     height_cm  weight_kg  nationality       club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
# highest earning players in liverpool club
liver.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 9      209331  https://sofifa.com/player/209331/mohamed-salah...
# 39     208722  https://sofifa.com/player/208722/sadio-mane/20...
# 7      203376  https://sofifa.com/player/203376/virgil-van-di...
# 63     201942  https://sofifa.com/player/201942/roberto-firmi...
# 13     212831  https://sofifa.com/player/212831/alisson-ramse...
#
#          short_name                            long_name  age         dob  \
# 9          M. Salah                 Mohamed  Salah Ghaly   27  1992-06-15
# 39          S. Mané                           Sadio Mané   27  1992-04-10
# 7       V. van Dijk                      Virgil van Dijk   27  1991-07-08
# 63  Roberto Firmino  Roberto Firmino Barbosa de Oliveira   27  1991-10-02
# 13          Alisson                Alisson Ramses Becker   26  1992-10-02
#
#     height_cm  weight_kg  nationality       club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
# top defending players in liverpool club
liver.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 7       203376  https://sofifa.com/player/203376/virgil-van-di...
# 81      209499  https://sofifa.com/player/209499/fabio-henriqu...
# 260     197061  https://sofifa.com/player/197061/joel-matip/20...
# 542     195086  https://sofifa.com/player/195086/dejan-lovren/...
# 82      216267  https://sofifa.com/player/216267/andrew-robert...
#
#        short_name               long_name  age         dob  height_cm  \
# 7     V. van Dijk         Virgil van Dijk   27  1991-07-08        193
# 81        Fabinho  Fábio Henrique Tavares   25  1993-10-23        188
# 260      J. Matip    Joël Andre Job Matip   27  1991-08-08        194
# 542     D. Lovren            Dejan Lovren   29  1989-07-05        188
# 82   A. Robertson        Andrew Robertson   25  1994-03-11        178
#
#      weight_kg  nationality       club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
# top shooting players in liverpool club
liver.sort_values(by=['shooting'],ascending=False).head(10)
# Out:
#      sofifa_id                                         player_url  \
# 9       209331  https://sofifa.com/player/209331/mohamed-salah...
# 39      208722  https://sofifa.com/player/208722/sadio-mane/20...
# 63      201942  https://sofifa.com/player/201942/roberto-firmi...
# 313     193348  https://sofifa.com/player/193348/xherdan-shaqi...
# 788     213135  https://sofifa.com/player/213135/divock-origi/...
# 139     181291  https://sofifa.com/player/181291/georginio-wij...
# 451     198784  https://sofifa.com/player/198784/alex-oxlade-c...
# 243     220971  https://sofifa.com/player/220971/naby-keita/20...
# 689     180819  https://sofifa.com/player/180819/adam-lallana/...
# 218     183711  https://sofifa.com/player/183711/jordan-hender...
#
#                 short_name                            long_name  age  \
# 9                 M. Salah                 Mohamed  Salah Ghaly   27
# 39                 S. Mané                           Sadio Mané   27
# ...

# %%
liver['nationality'].value_counts()
# Out:
# England                13
# Netherlands             4
# Brazil                  3
# Spain                   2
# Egypt                   1
# Senegal                 1
# Scotland                1
# Guinea                  1
# Cameroon                1
# Switzerland             1
# Croatia                 1
# Belgium                 1
# Germany                 1
# Algeria                 1
# Republic of Ireland     1
# Name: nationality, dtype: int64
